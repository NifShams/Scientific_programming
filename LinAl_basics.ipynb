# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.linalg import solve_triangular , solve_toeplitz , toeplitz , eigh_tridiagonal , fiedler, lu , cholesky , kron 

#Triangular Matrix 
A_0 = np.array([[3, 0, 0, 0],
              [2, 1, 0, 0],
              [1, 0, 1, 0],
              [1, 1, 1, 1]])
b_0 = np.array([4, 2, 4, 2])

x_0 = solve_triangular(A_0 , b_0 , lower = True)




#Toeplitz Matrix
# The toeplitz matrix can be specified uniquely by its first column and the first row

col = np.array([1,3,6,10])
row = np.array([1 , -1, 2, 3])

b_1 = np.array ([1, 2, 2, 5])
x_1 = solve_toeplitz ( (col , row ) , b_1)




# Eigenvalue problems

d = 3 * np.ones(4)
e = -1 * np.ones(3)

w , v = eigh_tridiagonal (d , e)
v = v.T

A_1 = np.diag(d) + np.diag(e , k = 1) + np.diag(e , k = -1)



#Special Matrices 

fieldler_matrix = fiedler ([1,4,12,45])
toeplitz_matrix = toeplitz([1,2,3,6,0,0], [1,4,5,6,0,0])



#Decompositions

#LU
Q = np.array([[2, 5, 8, 7], [5, 2, 2, 8], [7, 5, 6, 6], [5, 4, 4, 8]])
p , l , u = lu(Q)

#Cholesky
W = np.array([[1,0.2],[0.2,1]])
C = cholesky(W , lower = True )
